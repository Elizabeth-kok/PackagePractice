# %% [markdown]
# ## PyCaret-AnomalyDetection

# %%
pip install -q pycaret
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Train Model

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("creditcarddata.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df.Class.value_counts()
# Out:
# 0.0    54513
# 1.0      155
# Name: Class, dtype: int64

# %% [markdown]
# ### Test Model

# %%
from pycaret.anomaly import setup,create_model,assign_model,evaluate_model,predict_model,save_model,load_model

# %%
s=setup(df)
# Out:
# <style type="text/css">
# #T_f8618_row2_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f8618_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8618_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8618_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f8618_row0_col1" class="data row0 col1" >2492</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8618_row1_col0" class="data row1 col0" >Original Data</td>
#       <td id="T_f8618_row1_col1" class="data row1 col1" >(93583, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8618_row2_col0" class="data row2 col0" >Missing Values</td>
#       <td id="T_f8618_row2_col1" class="data row2 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8618_row3_col0" class="data row3 col0" >Numeric Features</td>
#       <td id="T_f8618_row3_col1" class="data row3 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8618_row4_col0" class="data row4 col0" >Categorical Features</td>
#       <td id="T_f8618_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f8618_row5_col0" class="data row5 col0" >Ordinal Features</td>
#       <td id="T_f8618_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f8618_row6_col0" class="data row6 col0" >High Cardinality Features</td>
#       <td id="T_f8618_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f8618_row7_col0" class="data row7 col0" >High Cardinality Method</td>
#       <td id="T_f8618_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f8618_row8_col0" class="data row8 col0" >Transformed Data</td>
#       <td id="T_f8618_row8_col1" class="data row8 col1" >(93583, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f8618_row9_col0" class="data row9 col0" >CPU Jobs</td>
#       <td id="T_f8618_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f8618_row10_col0" class="data row10 col0" >Use GPU</td>
#       <td id="T_f8618_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f8618_row11_col0" class="data row11 col0" >Log Experiment</td>
#       <td id="T_f8618_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f8618_row12_col0" class="data row12 col0" >Experiment Name</td>
#       <td id="T_f8618_row12_col1" class="data row12 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f8618_row13_col0" class="data row13 col0" >USI</td>
#       <td id="T_f8618_row13_col1" class="data row13 col1" >3da2</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f8618_row14_col0" class="data row14 col0" >Imputation Type</td>
#       <td id="T_f8618_row14_col1" class="data row14 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f8618_row15_col0" class="data row15 col0" >Iterative Imputation Iteration</td>
#       <td id="T_f8618_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f8618_row16_col0" class="data row16 col0" >Numeric Imputer</td>
#       <td id="T_f8618_row16_col1" class="data row16 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f8618_row17_col0" class="data row17 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_f8618_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f8618_row18_col0" class="data row18 col0" >Categorical Imputer</td>
#       <td id="T_f8618_row18_col1" class="data row18 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f8618_row19_col0" class="data row19 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_f8618_row19_col1" class="data row19 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f8618_row20_col0" class="data row20 col0" >Unknown Categoricals Handling</td>
#       <td id="T_f8618_row20_col1" class="data row20 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f8618_row21_col0" class="data row21 col0" >Normalize</td>
#       <td id="T_f8618_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f8618_row22_col0" class="data row22 col0" >Normalize Method</td>
#       <td id="T_f8618_row22_col1" class="data row22 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f8618_row23_col0" class="data row23 col0" >Transformation</td>
#       <td id="T_f8618_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f8618_row24_col0" class="data row24 col0" >Transformation Method</td>
#       <td id="T_f8618_row24_col1" class="data row24 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f8618_row25_col0" class="data row25 col0" >PCA</td>
#       <td id="T_f8618_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_f8618_row26_col0" class="data row26 col0" >PCA Method</td>
#       <td id="T_f8618_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_f8618_row27_col0" class="data row27 col0" >PCA Components</td>
#       <td id="T_f8618_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_f8618_row28_col0" class="data row28 col0" >Ignore Low Variance</td>
#       <td id="T_f8618_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_f8618_row29_col0" class="data row29 col0" >Combine Rare Levels</td>
#       <td id="T_f8618_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8618_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_f8618_row30_col0" class="data row30 col0" >Rare Level Threshold</td>
#       <td id="T_f8618_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
#       <th id=

# %%
best_model=create_model("knn")

# %%
best_model
# Out:
# KNN(algorithm='auto', contamination=0.05, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#   radius=1.0)

# %%
assign_model(best_model)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0       0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1       0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...     ...       ...       ...       ...       ...       ...       ...
# 93578   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 93579   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 93580   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 93581   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 93582   NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#              V7        V8        V9  ...       V23       V24       V25  \
# 0      0.239599  0.098698  0.363787  ... -0.110474  0.066928  0.128539
# 1     -0.078803  0.085102 -0.255425  ...  0.101288 -0.339846  0.167170
# 2      0.791461  0.247676 -1.514654  ...  0.909412 -0.689281 -0.327642
# 3      0.237609  0.377436 -1.387024  ... -0.190321 -1.175575  0.647376
# 4      0.592941 -0.270533  0.817739  ... -0.137458  0.141267 -0.206010
# ...         ...       ...       ...  ...       ...       ...       ...
# 93578       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 93579       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 93580       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 93581       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 93582       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V26       V27       V28  Amount  Class  Anomaly  Anomaly_Score
# 0     -0.189115  0.133558 -0.021053  149.62    0.0        1      51.254293
# 1      0.125895 -0.008983  0.014724    2.69    0.0        0      13.591730
# 2     -0.139097 -0.055353 -0.059752  378.66    0.0        1     147.808260
# 3     -0.221929  0.062723  0.061458  123.50    0.0        0      48.283279
# 4      0.502292  0.219422  0.215153   69.99    0.0        0      35.332948
# ...         ...       ...       ...     ...    ...      ...            ...
# 93578       NaN       NaN       NaN     NaN    NaN        0       0.000000
# 93579       NaN       NaN       NaN     NaN    NaN        0       0.000000
# 93580       NaN       NaN       NaN     NaN    NaN        0       0.000000
# 93581       NaN       NaN       NaN     NaN    NaN        0       0.000000
# 93582       NaN       NaN       NaN     NaN    NaN        0       0.000000
#
# [93583 rows x 33 columns]

# %% [markdown]
# ### Evaluate Model

# %%
evaluate_model(best_model)

# %% [markdown]
# ### Predict Model

# %%
predict_model(best_model,data=df)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0       0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1       0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...     ...       ...       ...       ...       ...       ...       ...
# 93578   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 93579   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 93580   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 93581   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 93582   NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#              V7        V8        V9  ...       V23       V24       V25  \
# 0      0.239599  0.098698  0.363787  ... -0.110474  0.066928  0.128539
# 1     -0.078803  0.085102 -0.255425  ...  0.101288 -0.339846  0.167170
# 2      0.791461  0.247676 -1.514654  ...  0.909412 -0.689281 -0.327642
# 3      0.237609  0.377436 -1.387024  ... -0.190321 -1.175575  0.647376
# 4      0.592941 -0.270533  0.817739  ... -0.137458  0.141267 -0.206010
# ...         ...       ...       ...  ...       ...       ...       ...
# 93578       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 93579       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 93580       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 93581       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 93582       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V26       V27       V28  Amount  Class  Anomaly  Anomaly_Score
# 0     -0.189115  0.133558 -0.021053  149.62    0.0        0      48.635328
# 1      0.125895 -0.008983  0.014724    2.69    0.0        0      12.302328
# 2     -0.139097 -0.055353 -0.059752  378.66    0.0        1     142.851957
# 3     -0.221929  0.062723  0.061458  123.50    0.0        0      38.526233
# 4      0.502292  0.219422  0.215153   69.99    0.0        0      30.130505
# ...         ...       ...       ...     ...    ...      ...            ...
# 93578       NaN       NaN       NaN     NaN    NaN        0       0.000000
# 93579       NaN       NaN       NaN     NaN    NaN        0       0.000000
# 93580       NaN       NaN       NaN     NaN    NaN        0       0.000000
# 93581       NaN       NaN       NaN     NaN    NaN        0       0.000000
# 93582       NaN       NaN       NaN     NaN    NaN        0       0.000000
#
# [93583 rows x 33 columns]

# %% [markdown]
# ### Save Model

# %%
save_model(best_model,"knn")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],
#                                        target='UNSUPERVISED_DUMMY_TARGET',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='most frequent',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None...
#                  ('fix_perfect', 'passthrough'),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   KNN(algorithm='auto', contamination=0.05, leaf_size=30, method='largest',
#    metric='minkowski', metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#    radius=1.0)]],
#           verbose=False),
#  'knn.pkl')

# %% [markdown]
# ### Load Model

# %%
model=load_model("knn")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
model
# Out:
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[],
#                                       target='UNSUPERVISED_DUMMY_TARGET',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='most frequent',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None...
#                 ('fix_perfect', 'passthrough'),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                 ['trained_model',
#                  KNN(algorithm='auto', contamination=0.05, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#   radius=1.0)]],
#          verbose=False)

# %% [markdown]
# k-Means Clustering is an unsupervised learning algorithm that is used for clustering whereas KNN is a supervised learning algorithm used for classification
