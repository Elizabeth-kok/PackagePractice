# %% [markdown]
# ## Hugging face diffusers package

# %%
# !pip install diffusers transformers
from diffusers import DiffusionPipeline

model_id = "CompVis/ldm-text2im-large-256"

# load model and scheduler
ldm = DiffusionPipeline.from_pretrained(model_id)

# run pipeline in inference (sample random noise and denoise)
prompt = "A painting of a squirrel eating a burger"
images = ldm([prompt], num_inference_steps=50, eta=0.3, guidance_scale=6)["sample"]

# save images
for idx, image in enumerate(images):
    image.save(f"squirrel-{idx}.png")

# %%
# !pip install -q diffusers transformers
# Out:
# WARNING: You are using pip version 22.0.4; however, version 22.2 is available.
# You should consider upgrading via the '/Users/elizabeth/.pyenv/versions/3.8.12/envs/lewagon/bin/python3.8 -m pip install --upgrade pip' command.

# %%
from diffusers import DiffusionPipeline

# %%
#use google colab next time!! taking too long to download

model_id = "CompVis/ldm-text2im-large-256"

# load model and scheduler
ldm = DiffusionPipeline.from_pretrained(model_id)
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.96k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/118k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/108k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/98.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/80.8k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/376 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/713 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.49G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/522 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]

# %%
prompt = "A baby pink brocolli"
images = ldm([prompt], num_inference_steps=50, eta=0.3, guidance_scale=6)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
images
# Out:
# {'sample': [<PIL.Image.Image image mode=RGB size=256x256 at 0x117563280>]}

# %%
images["sample"] # output is a list
# Out:
# [<PIL.Image.Image image mode=RGB size=256x256 at 0x117563280>]

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(images["sample"][0])

# %%
prompt = "A crocodile and a mango"
plt.show(images[0])
